# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
#display.clear_output()
#!yolo mode=checks

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="6nRIYo2K47HgTtWcijLV")
project = rf.workspace("betul-9otjz").project("insect-detection-uk1v2")
dataset = project.version(8).download("yolov8")

# %%
# Load a model
model = YOLO('yolov8m.pt')  # load a partially trained model
results = model.train(data = "/content/Insect-Detection-8/data.yaml", epochs=100, imgsz=640)
# Out:
# Ultralytics YOLOv8.0.221 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import torch

the_best = YOLO("/content/runs/detect/train2/weights/best.pt")
torch.save(the_best, 'yolov8_modelbestlast.pt')

# %%
Image(filename=f'/content/runs/detect/train2/confusion_matrix.png',width=1000)

# %%
Image(filename=f'/content/runs/detect/train2/results.png',width=1000)

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !yolo task=detect mode=predict model= /content/runs/detect/train2/weights/best.pt conf=0.5 source={dataset.location}/test/images

# %%
import glob
from IPython.display import Image,display

i=0
for image_path in glob.glob(f'/content/runs/detect/predict/*.jpg'):
  display(Image(filename=image_path,height=300))
  print("\n")
  i=i+1
  if i == 10:
    break

# %%
# !cp -r /content/runs/detect/predict /content/drive/MyDrive/ColabNotebooks/InsectDetection/outputs

# %%
# !yolo task=detect mode=predict model= /content/runs/detect/train2/weights/best.pt conf=0.7 source=/content/drive/MyDrive/ColabNotebooks/InsectDetection/testingvideos
# Out:
# Ultralytics YOLOv8.0.221 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25848445 parameters, 0 gradients, 78.7 GFLOPs
#
# video 1/6 (1/51) /content/drive/MyDrive/ColabNotebooks/InsectDetection/testingvideos/arıtest.mp4: 384x640 4 Africanized Honey Beess, 213.8ms
# video 1/6 (2/51) /content/drive/MyDrive/ColabNotebooks/InsectDetection/testingvideos/arıtest.mp4: 384x640 1 Africanized Honey Bees, 25.9ms
# video 1/6 (3/51) /content/drive/MyDrive/ColabNotebooks/InsectDetection/testingvideos/arıtest.mp4: 384x640 3 Africanized Honey Beess, 25.8ms
# video 1/6 (4/51) /content/drive/MyDrive/ColabNotebooks/InsectDetection/testingvideos/arıtest.mp4: 384x640 2 Africanized Honey Beess, 25.8ms
# video 1/6 (5/51) /content/drive/MyDrive/ColabNotebooks/InsectDetection/testingvideos/arıtest.mp4: 384x640 3 Africanized Honey Beess, 25.8ms
# ...

# %%
# !cp -r /content/runs/detect/predict2 /content/drive/MyDrive/ColabNotebooks/InsectDetection/outputs

# %%
# !cp -r /content/runs/detect/train2 /content/drive/MyDrive/ColabNotebooks/InsectDetection/outputs
